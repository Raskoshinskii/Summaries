# %% [markdown]
# # Iris

# %% [markdown]
# ### Introduction:
#
# This exercise may seem a little bit strange, but keep doing it.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called iris

# %%
path = 'D:/ML/Books/Learning_Pandas_russian_translation-1-master/pandas_exercises-master/pandas_exercises-master/Data/iris.data'
data = pd.read_csv(path)
data.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
data.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %% [markdown]
# ### Step 4. Create columns for the dataset

# %%
# My solution 
data.rename(columns= {'5.1':'sepal_length',
                      '3.5':'sepal_width',
                      '1.4':'petal_length',
                      '0.2':'petal_width',
                      'Iris-setosa':'Class'           
                      },inplace=True)
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        Class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
# Better Solution 
new_col_names = ['sepal_length','sepal_width','petal_length','petal_width','Class']
data.columns = new_col_names
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        Class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %% [markdown]
# ### Step 5.  Is there any missing value in the dataframe?

# %%
data.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# Class           0
# dtype: int64

# %% [markdown]
# ### Step 6.  Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
data.loc[10:29,'petal_length'] = np.nan
data.head(20)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        Class
# 0            4.9          3.0           1.4          0.2  Iris-setosa
# 1            4.7          3.2           1.3          0.2  Iris-setosa
# 2            4.6          3.1           1.5          0.2  Iris-setosa
# 3            5.0          3.6           1.4          0.2  Iris-setosa
# 4            5.4          3.9           1.7          0.4  Iris-setosa
# 5            4.6          3.4           1.4          0.3  Iris-setosa
# 6            5.0          3.4           1.5          0.2  Iris-setosa
# 7            4.4          2.9           1.4          0.2  Iris-setosa
# 8            4.9          3.1           1.5          0.1  Iris-setosa
# 9            5.4          3.7           1.5          0.2  Iris-setosa
# 10           4.8          3.4           NaN          0.2  Iris-setosa
# 11           4.8          3.0           NaN          0.1  Iris-setosa
# ...

# %% [markdown]
# ### Step 7. Good, now lets substitute the NaN values to 1.0

# %%
data.fillna(1,inplace=True)
data.isna().sum()[2]
# Out:
# 0

# %% [markdown]
# ### Step 8. Now let's delete the column class

# %%
del data['Class']
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           4.9          3.0           1.4          0.2
# 1           4.7          3.2           1.3          0.2
# 2           4.6          3.1           1.5          0.2
# 3           5.0          3.6           1.4          0.2
# 4           5.4          3.9           1.7          0.4

# %% [markdown]
# ### Step 9.  Set the first 3 rows as NaN

# %%
data.iloc[:3] = np.nan
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1           NaN          NaN           NaN          NaN
# 2           NaN          NaN           NaN          NaN
# 3           5.0          3.6           1.4          0.2
# 4           5.4          3.9           1.7          0.4

# %% [markdown]
# ### Step 10.  Delete the rows that have NaN

# %%
data.dropna(inplace=True)
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 3           5.0          3.6           1.4          0.2
# 4           5.4          3.9           1.7          0.4
# 5           4.6          3.4           1.4          0.3
# 6           5.0          3.4           1.5          0.2
# 7           4.4          2.9           1.4          0.2

# %% [markdown]
# ### Step 11. Reset the index so it begins with 0 again

# %%
data.reset_index(drop=True)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.0          3.6           1.4          0.2
# 1             5.4          3.9           1.7          0.4
# 2             4.6          3.4           1.4          0.3
# 3             5.0          3.4           1.5          0.2
# 4             4.4          2.9           1.4          0.2
# ..            ...          ...           ...          ...
# 141           6.7          3.0           5.2          2.3
# 142           6.3          2.5           5.0          1.9
# 143           6.5          3.0           5.2          2.0
# 144           6.2          3.4           5.4          2.3
# 145           5.9          3.0           5.1          1.8
#
# [146 rows x 4 columns]
