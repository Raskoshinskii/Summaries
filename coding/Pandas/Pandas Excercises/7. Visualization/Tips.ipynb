# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 

# %matplotlib inline
sns.set_style('white')

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
path = 'D:/ML/Books/Learning_Pandas_russian_translation-1-master/pandas_exercises-master/pandas_exercises-master/Data/tips.csv'
data = pd.read_csv(path,sep=',')
data.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
# Distribution Creation
bill_dist = sns.distplot(data.total_bill);

# Labels and Title Setting 
bill_dist.set(xlabel='Total Bill Value',ylabel='Frequency',title='Total Bill Distribution')

# take out the right and upper borders
sns.despine()

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
# My solution
plt.scatter(data['total_bill'],data['tip'])
plt.title('Total Bill ~ Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip');

# %%
# Author's solution
sns.jointplot(x='total_bill', y='tip',data = data);

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
sns.pairplot(data);

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
# My solution 
plt.scatter(data['day'],data['total_bill']);

# %%
# Author's solution 
sns.stripplot(x='day',y='total_bill',data=data,jitter=True);

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
sns.stripplot(x='tip',y='day',hue='sex',data=data,jitter=True);

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
sns.boxplot(x='day',y='total_bill',hue='time',data=data);

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
# Let's provide a better style 
sns.set_style('ticks')

g = sns.FacetGrid(data,col='time')
g.map(plt.hist,'tip');

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
g = sns.FacetGrid(data,col='sex',hue='smoker')
g.map(plt.scatter,'total_bill','tip');

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.
